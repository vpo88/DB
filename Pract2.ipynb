# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
student = pd.read_csv("StudentDB.csv")

# %%
student
# Out:
#    Gender  MathScore  ReadingScore  WritingScore  PlacementScore ClubJoinDate  \
# 0       M         95            84            90              85   2022-10-14
# 1       F         75            95            85              75   2022-08-10
# 2       M         80            75            81              76   2021-07-31
# 3       F         61            85            91              94   2022-10-15
# 4       F         76            86            74              82   2022-08-11
# 5       F         85            84            73              81   2021-08-01
# 6       M         95            99            73              80   2022-10-16
# 7       M         86            91            80              93   2022-08-12
# 8       F         94            92            90              94   2022-08-13
# 9       F         84            94            94              75   2022-10-17
# 10      M         64            76            76              65   2022-08-13
# ...

# %%
student.isnull()
# Out:
#     Gender  MathScore  ReadingScore  WritingScore  PlacementScore  \
# 0    False      False         False         False           False
# 1    False      False         False         False           False
# 2    False      False         False         False           False
# 3    False      False         False         False           False
# 4    False      False         False         False           False
# 5    False      False         False         False           False
# 6    False      False         False         False           False
# 7    False      False         False         False           False
# 8    False      False         False         False           False
# 9    False      False         False         False           False
# 10   False      False         False         False           False
# 11   False      False         False         False           False
# 12   False      False         False         False           False
# ...

# %%
student
# Out:
#    Gender  MathScore  ReadingScore  WritingScore  PlacementScore ClubJoinDate  \
# 0       M         95          84.0            90            85.0   2022-10-14
# 1       F         75          95.0            85            75.0   2022-08-10
# 2       M         80          75.0            81            76.0   2021-07-31
# 3       F         61          85.0            91            94.0   2022-10-15
# 4       F         76          86.0            74            82.0   2022-08-11
# 5       F         85          84.0            73            81.0   2021-08-01
# 6       M         95          99.0            73            80.0   2022-10-16
# 7       M         86          91.0            80            93.0   2022-08-12
# 8       F         94          92.0            90            94.0   2022-08-13
# 9       F         84          94.0            94            75.0   2022-10-17
# 10      M         64          76.0            76            65.0   2022-08-13
# ...

# %%
student.isnull()
# Out:
#     Gender  MathScore  ReadingScore  WritingScore  PlacementScore  \
# 0    False      False         False         False           False
# 1    False      False         False         False           False
# 2    False      False         False         False           False
# 3    False      False         False         False           False
# 4    False      False         False         False           False
# 5    False      False         False         False           False
# 6    False      False         False         False           False
# 7    False      False         False         False           False
# 8    False      False         False         False           False
# 9    False      False         False         False           False
# 10   False      False         False         False           False
# 11   False      False         False         False           False
# 12   False      False         False         False           False
# ...

# %%
series = pd.isnull(student["ReadingScore"])
student[series]
# Out:
#    Gender  MathScore  ReadingScore  WritingScore  PlacementScore ClubJoinDate  \
# 16      M         91           NaN            74            82.0   2022-08-15
#
#     PlacementOfferCount     Region
# 16                    9  Hyderabad

# %%
student.notnull()
# Out:
#     Gender  MathScore  ReadingScore  WritingScore  PlacementScore  \
# 0     True       True          True          True            True
# 1     True       True          True          True            True
# 2     True       True          True          True            True
# 3     True       True          True          True            True
# 4     True       True          True          True            True
# 5     True       True          True          True            True
# 6     True       True          True          True            True
# 7     True       True          True          True            True
# 8     True       True          True          True            True
# 9     True       True          True          True            True
# 10    True       True          True          True            True
# 11    True       True          True          True            True
# 12    True       True          True          True            True
# ...

# %%
series1 = pd.notnull(student["ReadingScore"])
student[series1]
# Out:
#    Gender  MathScore  ReadingScore  WritingScore  PlacementScore ClubJoinDate  \
# 0       M         95          84.0            90            85.0   2022-10-14
# 1       F         75          95.0            85            75.0   2022-08-10
# 2       M         80          75.0            81            76.0   2021-07-31
# 3       F         61          85.0            91            94.0   2022-10-15
# 4       F         76          86.0            74            82.0   2022-08-11
# 5       F         85          84.0            73            81.0   2021-08-01
# 6       M         95          99.0            73            80.0   2022-10-16
# 7       M         86          91.0            80            93.0   2022-08-12
# 8       F         94          92.0            90            94.0   2022-08-13
# 9       F         84          94.0            94            75.0   2022-10-17
# 10      M         64          76.0            76            65.0   2022-08-13
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
student['Gender'] = le.fit_transform(student['Gender'])
newstudent = student
student
# Out:
#     Gender  MathScore  ReadingScore  WritingScore  PlacementScore  \
# 0        1         95          84.0            90            85.0
# 1        0         75          95.0            85            75.0
# 2        1         80          75.0            81            76.0
# 3        0         61          85.0            91            94.0
# 4        0         76          86.0            74            82.0
# 5        0         85          84.0            73            81.0
# 6        1         95          99.0            73            80.0
# 7        1         86          91.0            80            93.0
# 8        0         94          92.0            90            94.0
# 9        0         84          94.0            94            75.0
# 10       1         64          76.0            76            65.0
# 11       0         73          73.0            86            86.0
# 12       0         75          71.0            87            76.0
# ...

# %%
missing_values = ["Na","na"]
student = pd.read_csv("StudentDB.csv",na_values = missing_values)
student
# Out:
#    Gender  MathScore  ReadingScore  WritingScore  PlacementScore ClubJoinDate  \
# 0       M         95          84.0            90            85.0   2022-10-14
# 1       F         75          95.0            85            75.0   2022-08-10
# 2       M         80          75.0            81            76.0   2021-07-31
# 3       F         61          85.0            91            94.0   2022-10-15
# 4       F         76          86.0            74            82.0   2022-08-11
# 5       F         85          84.0            73            81.0   2021-08-01
# 6       M         95          99.0            73            80.0   2022-10-16
# 7       M         86          91.0            80            93.0   2022-08-12
# 8       F         94          92.0            90            94.0   2022-08-13
# 9       F         84          94.0            94            75.0   2022-10-17
# 10      M         64          76.0            76            65.0   2022-08-13
# ...

# %%
nstudent=student
nstudent.fillna(0)
# Out:
#    Gender  MathScore  ReadingScore  WritingScore  PlacementScore ClubJoinDate  \
# 0       M         95          84.0            90            85.0   2022-10-14
# 1       F         75          95.0            85            75.0   2022-08-10
# 2       M         80          75.0            81            76.0   2021-07-31
# 3       F         61          85.0            91            94.0   2022-10-15
# 4       F         76          86.0            74            82.0   2022-08-11
# 5       F         85          84.0            73            81.0   2021-08-01
# 6       M         95          99.0            73            80.0   2022-10-16
# 7       M         86          91.0            80            93.0   2022-08-12
# 8       F         94          92.0            90            94.0   2022-08-13
# 9       F         84          94.0            94            75.0   2022-10-17
# 10      M         64          76.0            76            65.0   2022-08-13
# ...

# %%
nstudent.dropna()
# Out:
#    Gender  MathScore  ReadingScore  WritingScore  PlacementScore ClubJoinDate  \
# 0       M         95          84.0            90            85.0   2022-10-14
# 1       F         75          95.0            85            75.0   2022-08-10
# 2       M         80          75.0            81            76.0   2021-07-31
# 3       F         61          85.0            91            94.0   2022-10-15
# 4       F         76          86.0            74            82.0   2022-08-11
# 5       F         85          84.0            73            81.0   2021-08-01
# 6       M         95          99.0            73            80.0   2022-10-16
# 7       M         86          91.0            80            93.0   2022-08-12
# 8       F         94          92.0            90            94.0   2022-08-13
# 9       F         84          94.0            94            75.0   2022-10-17
# 10      M         64          76.0            76            65.0   2022-08-13
# ...

# %%
nstudent.dropna(how='all')
# Out:
#    Gender  MathScore  ReadingScore  WritingScore  PlacementScore ClubJoinDate  \
# 0       M         95          84.0            90            85.0   2022-10-14
# 1       F         75          95.0            85            75.0   2022-08-10
# 2       M         80          75.0            81            76.0   2021-07-31
# 3       F         61          85.0            91            94.0   2022-10-15
# 4       F         76          86.0            74            82.0   2022-08-11
# 5       F         85          84.0            73            81.0   2021-08-01
# 6       M         95          99.0            73            80.0   2022-10-16
# 7       M         86          91.0            80            93.0   2022-08-12
# 8       F         94          92.0            90            94.0   2022-08-13
# 9       F         84          94.0            94            75.0   2022-10-17
# 10      M         64          76.0            76            65.0   2022-08-13
# ...

# %%
nstudent.dropna(axis = 1)
# Out:
#    Gender  MathScore  WritingScore  PlacementOfferCount
# 0       M         95            90                    3
# 1       F         75            85                    4
# 2       M         80            81                    5
# 3       F         61            91                    7
# 4       F         76            74                    1
# 5       F         85            73                    8
# 6       M         95            73                    2
# 7       M         86            80                    4
# 8       F         94            90                    6
# 9       F         84            94                    8
# 10      M         64            76                    4
# 11      F         73            86                    4
# 12      F         75            87                    5
# 13      M         76            88                    6
# 14      M         78            89                    8
# 15      M         94            90                    2
# ...

# %%
new_student = nstudent.dropna(axis = 0, how ='any')
new_student
# Out:
#    Gender  MathScore  ReadingScore  WritingScore  PlacementScore ClubJoinDate  \
# 0       M         95          84.0            90            85.0   2022-10-14
# 1       F         75          95.0            85            75.0   2022-08-10
# 2       M         80          75.0            81            76.0   2021-07-31
# 3       F         61          85.0            91            94.0   2022-10-15
# 4       F         76          86.0            74            82.0   2022-08-11
# 5       F         85          84.0            73            81.0   2021-08-01
# 6       M         95          99.0            73            80.0   2022-10-16
# 7       M         86          91.0            80            93.0   2022-08-12
# 8       F         94          92.0            90            94.0   2022-08-13
# 9       F         84          94.0            94            75.0   2022-10-17
# 10      M         64          76.0            76            65.0   2022-08-13
# ...

# %%
col = ['MathScore','ReadingScore','WritingScore','PlacementScore']
student.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(student['MathScore']>90))
print(np.where(student['ReadingScore']<25))
print(np.where(student['WritingScore']<30))
# Out:
# (array([ 0,  6,  8, 15, 16, 17, 19, 26, 27, 28, 29]),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(student['PlacementScore'], student['PlacementOfferCount'])
plt.show()

# %%
print(np.where((student['PlacementScore']<50) & (student['PlacementOfferCount']>1)))
print(np.where((student['PlacementOfferCount']<3 & (student['PlacementScore']>85) )))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
col = ['ReadingScore']
student.boxplot(col)
plt.show()
