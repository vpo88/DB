# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ed=pd.read_csv("Employee_Data.csv")

# %%
ed
# Out:
#     ID  Experience_Years  Age  Gender    Salary
# 0    1                 5   28  Female    250000
# 1    2                 1   21    Male     50000
# 2    3                 3   23  Female    170000
# 3    4                 2   22    Male     25000
# 4    5                 1   17    Male     10000
# 5    6                25   62    Male   5001000
# 6    7                19   54  Female    800000
# 7    8                 2   21  Female      9000
# 8    9                10   36  Female     61500
# 9   10                15   54  Female    650000
# 10  11                 4   26  Female    250000
# 11  12                 6   29    Male   1400000
# 12  13                14   39    Male   6000050
# 13  14                11   40    Male    220100
# 14  15                 2   23    Male      7500
# 15  16                 4   27  Female     87000
# 16  17                10   34  Female    930000
# 17  18                15   54  Female   7900000
# 18  19                 2   21    Male     15000
# ...

# %%
ed.mean()
# Out:
# /tmp/ipykernel_22595/3687101760.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ed.mean()
# ID                  1.800000e+01
# Experience_Years    9.200000e+00
# Age                 3.548571e+01
# Salary              2.059147e+06
# dtype: float64

# %%
ed.loc[:,'Age'].mean()
# Out:
# 35.48571428571429

# %%
ed.mean(axis=1)[0:4]
# Out:
# /tmp/ipykernel_22595/676942913.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ed.mean(axis=1)[0:4]
# 0    62508.50
# 1    12506.00
# 2    42507.25
# 3     6257.00
# dtype: float64

# %%
ed.median()
# Out:
# /tmp/ipykernel_22595/3279234978.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ed.median()
# ID                      18.0
# Experience_Years         6.0
# Age                     29.0
# Salary              250000.0
# dtype: float64

# %%
ed.loc[:,'Age'].median()
# Out:
# 29.0

# %%
ed.median(axis=1)[0:10]
# Out:
# /tmp/ipykernel_22595/3964495804.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ed.median(axis=1)[0:10]
# 0    16.5
# 1    11.5
# 2    13.0
# 3    13.0
# 4    11.0
# 5    43.5
# 6    36.5
# 7    14.5
# 8    23.0
# 9    34.5
# dtype: float64

# %%
ed.mode()
# Out:
#     ID  Experience_Years   Age  Gender    Salary
# 0    1               2.0  54.0  Female   25000.0
# 1    2               NaN   NaN     NaN  250000.0
# 2    3               NaN   NaN     NaN       NaN
# 3    4               NaN   NaN     NaN       NaN
# 4    5               NaN   NaN     NaN       NaN
# 5    6               NaN   NaN     NaN       NaN
# 6    7               NaN   NaN     NaN       NaN
# 7    8               NaN   NaN     NaN       NaN
# 8    9               NaN   NaN     NaN       NaN
# 9   10               NaN   NaN     NaN       NaN
# 10  11               NaN   NaN     NaN       NaN
# 11  12               NaN   NaN     NaN       NaN
# 12  13               NaN   NaN     NaN       NaN
# 13  14               NaN   NaN     NaN       NaN
# 14  15               NaN   NaN     NaN       NaN
# 15  16               NaN   NaN     NaN       NaN
# 16  17               NaN   NaN     NaN       NaN
# 17  18               NaN   NaN     NaN       NaN
# ...

# %%
ed.loc[:,'Age'].mode()
# Out:
# 0    54
# Name: Age, dtype: int64

# %%
ed.min()
# Out:
# ID                       1
# Experience_Years         1
# Age                     17
# Gender              Female
# Salary                3000
# dtype: object

# %%
ed.loc[:,'Age'].min(skipna = False)
# Out:
# 17

# %%
ed.loc[:,'Age'].min(skipna = True)
# Out:
# 17

# %%
ed.max()
# Out:
# ID                        35
# Experience_Years          27
# Age                       62
# Gender                  Male
# Salary              10000000
# dtype: object

# %%
ed.loc[:,'Age'].max(skipna = False)
# Out:
# 62

# %%
ed.loc[:,'Age'].max(skipna = True)
# Out:
# 62

# %%
ed.std()
# Out:
# /tmp/ipykernel_22595/3633175234.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ed.std()
# ID                  1.024695e+01
# Experience_Years    7.552950e+00
# Age                 1.464355e+01
# Salary              3.170124e+06
# dtype: float64

# %%
ed.loc[:,'Age'].std()
# Out:
# 14.643551940884361

# %%
ed.std(axis=1)[0:4]
# Out:
# /tmp/ipykernel_22595/1971350628.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ed.std(axis=1)[0:4]
# 0    124994.333900
# 1     24996.001694
# 2     84995.167190
# 3     12495.336570
# dtype: float64

# %%
ed.groupby(['Gender'])['Age'].mean()
# Out:
# Gender
# Female    37.111111
# Male      33.764706
# Name: Age, dtype: float64

# %%
ed_u=ed.rename(columns= {'Salary':'Income'},inplace=False)
(ed_u.groupby(['Gender']).Income.mean())
# Out:
# Gender
# Female    2.054917e+06
# Male      2.063626e+06
# Name: Income, dtype: float64

# %%
from sklearn import preprocessing
enc = preprocessing.OneHotEncoder()
enc_ed = pd.DataFrame(enc.fit_transform(ed[['Gender']]).toarray())

# %%
enc_ed
# Out:
#       0    1
# 0   1.0  0.0
# 1   0.0  1.0
# 2   1.0  0.0
# 3   0.0  1.0
# 4   0.0  1.0
# 5   0.0  1.0
# 6   1.0  0.0
# 7   1.0  0.0
# 8   1.0  0.0
# 9   1.0  0.0
# 10  1.0  0.0
# 11  0.0  1.0
# 12  0.0  1.0
# 13  0.0  1.0
# 14  0.0  1.0
# 15  1.0  0.0
# 16  1.0  0.0
# 17  1.0  0.0
# 18  0.0  1.0
# 19  0.0  1.0
# 20  0.0  1.0
# 21  0.0  1.0
# 22  0.0  1.0
# 23  1.0  0.0
# 24  1.0  0.0
# 25  1.0  0.0
# 26  0.0  1.0
# 27  1.0  0.0
# 28  1.0  0.0
# 29  1.0  0.0
# 30  0.0  1.0
# 31  0.0  1.0
# 32  1.0  0.0
# 33  1.0  0.0
# 34  0.0  1.0

# %%
ed_encode=ed_u.join(enc_ed)
ed_encode
# Out:
#     ID  Experience_Years  Age  Gender    Income    0    1
# 0    1                 5   28  Female    250000  1.0  0.0
# 1    2                 1   21    Male     50000  0.0  1.0
# 2    3                 3   23  Female    170000  1.0  0.0
# 3    4                 2   22    Male     25000  0.0  1.0
# 4    5                 1   17    Male     10000  0.0  1.0
# 5    6                25   62    Male   5001000  0.0  1.0
# 6    7                19   54  Female    800000  1.0  0.0
# 7    8                 2   21  Female      9000  1.0  0.0
# 8    9                10   36  Female     61500  1.0  0.0
# 9   10                15   54  Female    650000  1.0  0.0
# 10  11                 4   26  Female    250000  1.0  0.0
# 11  12                 6   29    Male   1400000  0.0  1.0
# 12  13                14   39    Male   6000050  0.0  1.0
# 13  14                11   40    Male    220100  0.0  1.0
# 14  15                 2   23    Male      7500  0.0  1.0
# ...

# %%
import pandas as pd

# %%
csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

# %%
col_names =['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Species']

# %%
iris = pd.read_csv(csv_url, names = col_names)

# %%
iris
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
irisSet = (iris['Species']== 'Iris-setosa')

# %%
print('Iris-setosa')
print(iris[irisSet].describe())
# Out:
# Iris-setosa
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000

# %%
irisVer = (iris['Species']== 'Iris-versicolor')

# %%
print('Iris-versicolor')
print(iris[irisVer].describe())
# Out:
# Iris-versicolor
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
irisVir = (iris['Species']== 'Iris-virginica')

# %%
print('Iris-virginica')
print(iris[irisVir].describe())
# Out:
# Iris-virginica
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000
